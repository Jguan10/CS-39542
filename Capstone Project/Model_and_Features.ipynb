# %%
import pandas as pd

df = pd.read_csv("Data/Anime_Processed.csv")
df.head(10)
# Out:
#    anime_id                             Name             English name Score  \
# 0         1                     Cowboy Bebop             Cowboy Bebop  8.75
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie  8.38
# 2         6                           Trigun                   Trigun  8.22
# 3         7               Witch Hunter Robin       Witch Hunter Robin  7.25
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster  6.94
# 5        15                     Eyeshield 21                  UNKNOWN  7.92
# 6        16             Hachimitsu to Clover         Honey and Clover   8.0
# 7        17       Hungry Heart: Wild Striker                  UNKNOWN  7.55
# 8        18           Initial D Fourth Stage                  UNKNOWN  8.16
# 9        19                          Monster                  Monster  8.87
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# ...

# %%
df.info()

# %% [markdown]
# Prediction model using episodes, genres, source, synopsis, studios, producers

# %%
#%pip install tensorflow

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data/training_set.csv')
df.head(10)
# Out:
#    anime_id                            title  episodes  score  \
# 0         1                     Cowboy Bebop      26.0    9.0
# 1         5  Cowboy Bebop: Tengoku no Tobira       1.0    8.0
# 2         6                           Trigun      26.0    8.0
# 3         7               Witch Hunter Robin      26.0    7.0
# 4         8                   Bouken Ou Beet      52.0    7.0
# 5        15                     Eyeshield 21     145.0    8.0
# 6        16             Hachimitsu to Clover      24.0    8.0
# 7        17       Hungry Heart: Wild Striker      52.0    8.0
# 8        18           Initial D Fourth Stage      24.0    8.0
# 9        19                          Monster      74.0    9.0
#
#   Popularity_category Rank_category  Genres_Action  Genres_Adventure  \
# 0             Top 100       Top 100           True             False
# 1           Top 1,000       Top 500           True             False
# 2             Top 500       Top 500           True             False
# 3           Top 2,500     Top 5,000           True             False
# 4           Top 7,500     Top 5,000           True             False
# 5           Top 2,500     Top 1,000          False             False
# 6           Top 1,000     Top 1,000          False             False
# 7           Top 5,000     Top 2,500          False             False
# 8           Top 2,500       Top 500           True             False
# 9             Top 500       Top 100          False             False
#
#    Genres_Avant Garde  Genres_Award Winning  ...  producer_pony_canyon  \
# 0               False                 False  ...                 False
# 1               False                 False  ...                 False
# 2               False                 False  ...                 False
# 3               False                 False  ...                 False
# 4               False                 False  ...                 False
# 5               False                 False  ...                 False
# 6               False                 False  ...                 False
# 7               False                 False  ...                 False
# 8               False                 False  ...                 False
# 9               False                 False  ...                 False
#
#    producer_kadokawa  producer_dentsu  producer_fuji_tv  producer_nhk  \
# 0              False            False             False         False
# 1              False            False             False         False
# 2              False            False             False         False
# 3              False             True             False         False
# 4              False             True             False         False
# 5              False            False             False         False
# 6              False             True              True         False
# 7              False            False             False         False
# 8              False            False             False         False
# 9              False            False             False         False
#
#    producer_sotsu  producer_klockworx  producer_kodansha  producer_shueisha  \
# 0           False               False              False              False
# 1           False               False              False              False
# 2           False               False              False              False
# 3           False               False              False              False
# 4           False               False              False              False
# 5           False               False              False               True
# 6           False               False              False               True
# 7           False               False              False              False
# 8           False               False              False              False
# 9           False               False              False              False
#
#      year
# 0  1998.0
# 1     NaN
# 2  1998.0
# 3  2002.0
# 4  2004.0
# 5  2005.0
# 6  2005.0
# 7  2002.0
# 8  2004.0
# 9  2004.0
#
# [10 rows x 239 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21280 entries, 0 to 21279
# Columns: 239 entries, anime_id to year
# dtypes: bool(79), float64(154), int64(2), object(4)
# memory usage: 27.6+ MB

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
scaler = preprocessing.MinMaxScaler()
df[["episodes"]] = scaler.fit_transform(df[["episodes"]])

# %%
most_common = df["Popularity_category"].value_counts().idxmax()  
df["Popularity_category"] = df["Popularity_category"].replace("Unknown", most_common)

# %%
most_common = df["Rank_category"].value_counts().idxmax()  
df["Rank_category"] = df["Rank_category"].replace("Unknown", most_common)
df["Rank_category"] = df["Rank_category"].replace("Top 10", "Top 100")
df["Popularity_category"] = df["Popularity_category"].replace("Top 10", "Top 100")

# %%
df['score'] = df['score'].round().astype(int)
df['score'] = df['score'].astype(str)

# %%
#X_train = df.drop(columns=["anime_id","title","score", "popularity", "rank", "Popularity_category", "Rank_category", "studios"])
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(columns=["anime_id","title","score", "popularity", "rank", "Popularity_category", "Rank_category", "studios", "year"]),
    df[["score", "Popularity_category", "Rank_category"]],
    test_size=0.2, 
    random_state=42  
)

# %%
score_encoder = LabelEncoder()
popularity_encoder = LabelEncoder()
rank_encoder = LabelEncoder()

y_score_encoded = score_encoder.fit_transform(y_train['score'])

y_pop_encoded = popularity_encoder.fit_transform(y_train['Popularity_category'])

y_rank_encoded = rank_encoder.fit_transform(y_train['Rank_category'])

# %%
y_score = to_categorical(y_score_encoded)

y_pop = to_categorical(y_pop_encoded)

y_rank = to_categorical(y_rank_encoded)

# %%
input_layer = Input(shape=(X_train.shape[1],))
hidden_layer = Dense(64, activation='relu')(input_layer)
shared_layer = Dense(64, activation='relu')(input_layer)
shared_layer = Dense(64, activation='relu')(shared_layer)

# %%
score_output = Dense(y_score.shape[1], activation='softmax', name="score")(shared_layer)
popularity_output = Dense(y_pop.shape[1], activation='softmax', name="popularity")(shared_layer)
rank_output = Dense(y_rank.shape[1], activation='softmax', name="rank")(shared_layer)

# %%
model = Model(inputs=input_layer, outputs=[score_output, popularity_output, rank_output])

model.compile(optimizer='adam',
              loss={'score': 'categorical_crossentropy',
                    'popularity': 'categorical_crossentropy',
                    'rank': 'categorical_crossentropy'},
              metrics={
                  'score': ['accuracy'],
                  'popularity': ['accuracy'], 
                  'rank': ['accuracy']  
                  })

# %%
history = model.fit(X_train,
                    {'score': y_score, 'popularity': y_pop, 'rank': y_rank},
                    validation_split=0.2,
                    epochs=50,
                    batch_size=128)
# Out:
# Epoch 1/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 5.2616 - popularity_accuracy: 0.4633 - popularity_loss: 1.8328 - rank_accuracy: 0.3877 - rank_loss: 1.7894 - score_accuracy: 0.5069 - score_loss: 1.6393 - val_loss: 3.4406 - val_popularity_accuracy: 0.5633 - val_popularity_loss: 1.2668 - val_rank_accuracy: 0.5577 - val_rank_loss: 1.1890 - val_score_accuracy: 0.6279 - val_score_loss: 0.9868
# Epoch 2/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3241 - popularity_accuracy: 0.5647 - popularity_loss: 1.2185 - rank_accuracy: 0.5796 - rank_loss: 1.1405 - score_accuracy: 0.6272 - score_loss: 0.9651 - val_loss: 3.1593 - val_popularity_accuracy: 0.5818 - val_popularity_loss: 1.1183 - val_rank_accuracy: 0.5780 - val_rank_loss: 1.1182 - val_score_accuracy: 0.6358 - val_score_loss: 0.9241
# Epoch 3/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0837 - popularity_accuracy: 0.5687 - popularity_loss: 1.1072 - rank_accuracy: 0.5886 - rank_loss: 1.0787 - score_accuracy: 0.6485 - score_loss: 0.8977 - val_loss: 3.0669 - val_popularity_accuracy: 0.5962 - val_popularity_loss: 1.0689 - val_rank_accuracy: 0.5765 - val_rank_loss: 1.0955 - val_score_accuracy: 0.6367 - val_score_loss: 0.9032
# Epoch 4/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9824 - popularity_accuracy: 0.5869 - popularity_loss: 1.0634 - rank_accuracy: 0.6032 - rank_loss: 1.0506 - score_accuracy: 0.6518 - score_loss: 0.8683 - val_loss: 3.0260 - val_popularity_accuracy: 0.5965 - val_popularity_loss: 1.0537 - val_rank_accuracy: 0.5789 - val_rank_loss: 1.0833 - val_score_accuracy: 0.6420 - val_score_loss: 0.8891
# Epoch 5/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9479 - popularity_accuracy: 0.5884 - popularity_loss: 1.0519 - rank_accuracy: 0.6033 - rank_loss: 1.0353 - score_accuracy: 0.6477 - score_loss: 0.8608 - val_loss: 2.9852 - val_popularity_accuracy: 0.5997 - val_popularity_loss: 1.0391 - val_rank_accuracy: 0.5844 - val_rank_loss: 1.0702 - val_score_accuracy: 0.6452 - val_score_loss: 0.8761
# Epoch 6/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8977 - popularity_accuracy: 0.5959 - popularity_loss: 1.0365 - rank_accuracy: 0.6047 - rank_loss: 1.0256 - score_accuracy: 0.6634 - score_loss: 0.8357 - val_loss: 2.9701 - val_popularity_accuracy: 0.6003 - val_popularity_loss: 1.0337 - val_rank_accuracy: 0.5838 - val_rank_loss: 1.0627 - val_score_accuracy: 0.6502 - val_score_loss: 0.8738
# Epoch 7/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8497 - popularity_accuracy: 0.5991 - popularity_loss: 1.0132 - rank_accuracy: 0.6140 - rank_loss: 1.0079 - score_accuracy: 0.6704 - score_loss: 0.8286 - val_loss: 2.9594 - val_popularity_accuracy: 0.6021 - val_popularity_loss: 1.0321 - val_rank_accuracy: 0.5891 - val_rank_loss: 1.0601 - val_score_accuracy: 0.6570 - val_score_loss: 0.8678
# Epoch 8/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8061 - popularity_accuracy: 0.6089 - popularity_loss: 0.9985 - rank_accuracy: 0.6206 - rank_loss: 0.9980 - score_accuracy: 0.6758 - score_loss: 0.8095 - val_loss: 2.9470 - val_popularity_accuracy: 0.6097 - val_popularity_loss: 1.0258 - val_rank_accuracy: 0.5862 - val_rank_loss: 1.0544 - val_score_accuracy: 0.6573 - val_score_loss: 0.8671
# Epoch 9/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7445 - popularity_accuracy: 0.6204 - popularity_loss: 0.9801 - rank_accuracy: 0.6289 - rank_loss: 0.9664 - score_accuracy: 0.6834 - score_loss: 0.7979 - val_loss: 2.9492 - val_popularity_accuracy: 0.6000 - val_popularity_loss: 1.0228 - val_rank_accuracy: 0.5891 - val_rank_loss: 1.0565 - val_score_accuracy: 0.6526 - val_score_loss: 0.8697
# Epoch 10/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7339 - popularity_accuracy: 0.6209 - popularity_loss: 0.9770 - rank_accuracy: 0.6297 - rank_loss: 0.9670 - score_accuracy: 0.6822 - score_loss: 0.7898 - val_loss: 2.9496 - val_popularity_accuracy: 0.6015 - val_popularity_loss: 1.0194 - val_rank_accuracy: 0.5885 - val_rank_loss: 1.0538 - val_score_accuracy: 0.6449 - val_score_loss: 0.8763
# Epoch 11/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7087 - popularity_accuracy: 0.6177 - popularity_loss: 0.9642 - rank_accuracy: 0.6332 - rank_loss: 0.9589 - score_accuracy: 0.6885 - score_loss: 0.7857 - val_loss: 2.9473 - val_popularity_accuracy: 0.6023 - val_popularity_loss: 1.0208 - val_rank_accuracy: 0.5850 - val_rank_loss: 1.0553 - val_score_accuracy: 0.6532 - val_score_loss: 0.8719
# Epoch 12/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.
50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2003 - popularity_accuracy: 0.6711 - popularity_loss: 0.8392 - rank_accuracy: 0.7019 - rank_loss: 0.7674 - score_accuracy: 0.7751 - score_loss: 0.5937 - val_loss: 3.2053 - val_popularity_accuracy: 0.6015 - val_popularity_loss: 1.0688 - val_rank_accuracy: 0.5833 - val_rank_loss: 1.1688 - val_score_accuracy: 0.6452 - val_score_loss: 0.9675
# Epoch 35/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1755 - popularity_accuracy: 0.6787 - popularity_loss: 0.8223 - rank_accuracy: 0.7084 - rank_loss: 0.7590 - score_accuracy: 0.7673 - score_loss: 0.5942 - val_loss: 3.2285 - val_popularity_accuracy: 0.6021 - val_popularity_loss: 1.0762 - val_rank_accuracy: 0.5836 - val_rank_loss: 1.1762 - val_score_accuracy: 0.6420 - val_score_loss: 0.9754
# Epoch 36/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1795 - popularity_accuracy: 0.6793 - popularity_loss: 0.8177 - rank_accuracy: 0.7054 - rank_loss: 0.7646 - score_accuracy: 0.7655 - score_loss: 0.5972 - val_loss: 3.2451 - val_popularity_accuracy: 0.6009 - val_popularity_loss: 1.0742 - val_rank_accuracy: 0.5856 - val_rank_loss: 1.1868 - val_score_accuracy: 0.6394 - val_score_loss: 0.9833
# Epoch 37/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1741 - popularity_accuracy: 0.6745 - popularity_loss: 0.8304 - rank_accuracy: 0.7087 - rank_loss: 0.7497 - score_accuracy: 0.7705 - score_loss: 0.5940 - val_loss: 3.2649 - val_popularity_accuracy: 0.6009 - val_popularity_loss: 1.0775 - val_rank_accuracy: 0.5780 - val_rank_loss: 1.1918 - val_score_accuracy: 0.6320 - val_score_loss: 0.9955
# Epoch 38/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1437 - popularity_accuracy: 0.6830 - popularity_loss: 0.8152 - rank_accuracy: 0.7116 - rank_loss: 0.7504 - score_accuracy: 0.7755 - score_loss: 0.5782 - val_loss: 3.2780 - val_popularity_accuracy: 0.5982 - val_popularity_loss: 1.0787 - val_rank_accuracy: 0.5827 - val_rank_loss: 1.2009 - val_score_accuracy: 0.6370 - val_score_loss: 0.9987
# Epoch 39/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1423 - popularity_accuracy: 0.6784 - popularity_loss: 0.8206 - rank_accuracy: 0.7184 - rank_loss: 0.7386 - score_accuracy: 0.7759 - score_loss: 0.5830 - val_loss: 3.3056 - val_popularity_accuracy: 0.5950 - val_popularity_loss: 1.0870 - val_rank_accuracy: 0.5774 - val_rank_loss: 1.2109 - val_score_accuracy: 0.6320 - val_score_loss: 1.0073
# Epoch 40/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1223 - popularity_accuracy: 0.6761 - popularity_loss: 0.8120 - rank_accuracy: 0.7143 - rank_loss: 0.7373 - score_accuracy: 0.7760 - score_loss: 0.5730 - val_loss: 3.3155 - val_popularity_accuracy: 0.5959 - val_popularity_loss: 1.0870 - val_rank_accuracy: 0.5797 - val_rank_loss: 1.2174 - val_score_accuracy: 0.6396 - val_score_loss: 1.0110
# Epoch 41/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0844 - popularity_accuracy: 0.6925 - popularity_loss: 0.7983 - rank_accuracy: 0.7161 - rank_loss: 0.7203 - score_accuracy: 0.7847 - score_loss: 0.5658 - val_loss: 3.3503 - val_popularity_accuracy: 0.5953 - val_popularity_loss: 1.0933 - val_rank_accuracy: 0.5803 - val_rank_loss: 1.2289 - val_score_accuracy: 0.6305 - val_score_loss: 1.0270
# Epoch 42/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0583 - popularity_accuracy: 0.6922 - popularity_loss: 0.7912 - rank_accuracy: 0.7258 - rank_loss: 0.7092 - score_accuracy: 0.7889 - score_loss: 0.5580 - val_loss: 3.3589 - val_popularity_accuracy: 0.5971 - val_popularity_loss: 1.0949 - val_rank_accuracy: 0.5797 - val_rank_loss: 1.2347 - val_score_accuracy: 0.6341 - val_score_loss: 1.0293
# Epoch 43/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0485 - popularity_accuracy: 0.6881 - popularity_loss: 0.8029 - rank_accuracy: 0.7308 - rank_loss: 0.7017 - score_accuracy: 0.7946 - score_loss: 0.5439 - val_loss: 3.3903 - val_popularity_accuracy: 0.5912 - val_popularity_loss: 1.1057 - val_rank_accuracy: 0.5759 - val_rank_loss: 1.2455 - val_score_accuracy: 0.6285 - val_score_loss: 1.0396
# Epoch 44/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0564 - popularity_accuracy: 0.6865 - popularity_loss: 0.7982 - rank_accuracy: 0.7205 - rank_loss: 0.7146 - score_accuracy: 0.7933 - score_loss: 0.5436 - val_loss: 3.3970 - val_popularity_accuracy: 0.6000 - val_popularity_loss: 1.1027 - val_rank_accuracy: 0.5771 - val_rank_loss: 1.2489 - val_score_accuracy: 0.6288 - val_score_loss: 1.0460
# Epoch 45/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0333 - popularity_accuracy: 0.6924 - popularity_loss: 0.7841 - rank_accuracy: 0.7279 - rank_loss: 0.7063 - score_accuracy: 0.7923 - score_loss: 0.5428 - val_loss: 3.4208 - val_popularity_accuracy: 0.5997 - val_popularity_loss: 1.1040 - val_rank_accuracy: 0.5700 - val_rank_loss: 1.2601 - val_score_accuracy: 0.6297 - val_score_loss: 1.0571
# Epoch 46/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0074 - popularity_accuracy: 0.6878 - popularity_loss: 0.7930 - rank_accuracy: 0.7339 - rank_loss: 0.6868 - score_accuracy: 0.7990 - score_loss: 0.5276 - val_loss: 3.4415 - val_popularity_accuracy: 0.5991 - val_popularity_loss: 1.1147 - val_rank_accuracy: 0.5809 - val_rank_loss: 1.2661 - val_score_accuracy: 0.6302 - val_score_loss: 1.0596
# Epoch 47/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0022 - popularity_accuracy: 0.6890 - popularity_loss: 0.7948 - rank_accuracy: 0.7367 - rank_loss: 0.6848 - score_accuracy: 0.8022 - score_loss: 0.5227 - val_loss: 3.4625 - val_popularity_accuracy: 0.5971 - val_popularity_loss: 1.1158 - val_rank_accuracy: 0.5771 - val_rank_loss: 1.2775 - val_score_accuracy: 0.6217 - val_score_loss: 1.0700
# Epoch 48/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0222 - popularity_accuracy: 0.6909 - popularity_loss: 0.7939 - rank_accuracy: 0.7331 - rank_loss: 0.6965 - score_accuracy: 0.7984 - score_loss: 0.5318 - val_loss: 3.5044 - val_popularity_accuracy: 0.5994 - val_popularity_loss: 1.1257 - val_rank_accuracy: 0.5774 - val_rank_loss: 1.2896 - val_score_accuracy: 0.6256 - val_score_loss: 1.0885
# Epoch 49/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9955 - popularity_accuracy: 0.6972 - popularity_loss: 0.7780 - rank_accuracy: 0.7376 - rank_loss: 0.6913 - score_accuracy: 0.8003 - score_loss: 0.5262 - val_loss: 3.4964 - val_popularity_accuracy: 0.5947 - val_popularity_loss: 1.1214 - val_rank_accuracy: 0.5771 - val_rank_loss: 1.2894 - val_score_accuracy: 0.6250 - val_score_loss: 1.0850
# Epoch 50/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9645 - popularity_accuracy: 0.6977 - popularity_loss: 0.7741 - rank_accuracy: 0.7387 - rank_loss: 0.6746 - score_accuracy: 0.8053 - score_loss: 0.5158 - val_loss: 3.5405 - val_popularity_accuracy: 0.5971 - val_popularity_loss: 1.1353 - val_rank_accuracy: 0.5703 - val_rank_loss: 1.3058 - val_score_accuracy: 0.6232 - val_score_loss: 1.0988

# %%
y_pred = model.predict(X_test)
# Out:
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred_score = y_pred[0].argmax(axis=1)
y_pred_score = score_encoder.inverse_transform(y_pred_score)

y_pred_pop = y_pred[1].argmax(axis=1)
y_pred_pop = popularity_encoder.inverse_transform(y_pred_pop)

y_pred_rank = y_pred[2].argmax(axis=1)
y_pred_rank = rank_encoder.inverse_transform(y_pred_rank)

# %%
accuracy_score_score = accuracy_score(y_test['score'], y_pred_score)
accuracy_score_pop = accuracy_score(y_test['Popularity_category'], y_pred_pop)
accuracy_score_rank = accuracy_score(y_test['Rank_category'], y_pred_rank)

print(f"Accuracy for Score Prediction: {accuracy_score_score:.4f}")
print(f"Accuracy for Popularity Category Prediction: {accuracy_score_pop:.4f}")
print(f"Accuracy for Rank Category Prediction: {accuracy_score_rank:.4f}")
# Out:
# Accuracy for Score Prediction: 0.6302
# Accuracy for Popularity Category Prediction: 0.5839
# Accuracy for Rank Category Prediction: 0.5865

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm_score = confusion_matrix(y_test['score'], y_pred_score, labels=score_encoder.classes_)
cm_pop = confusion_matrix(y_test['Popularity_category'], y_pred_pop, labels=popularity_encoder.classes_)
cm_rank = confusion_matrix(y_test['Rank_category'], y_pred_rank, labels=rank_encoder.classes_)

fig, axs = plt.subplots(1, 3, figsize=(18, 5))

disp_score = ConfusionMatrixDisplay(confusion_matrix=cm_score, display_labels=score_encoder.classes_)
disp_score.plot(cmap=plt.cm.Blues, ax=axs[0], xticks_rotation='vertical')
axs[0].set_title('Confusion Matrix for Score Prediction')

disp_pop = ConfusionMatrixDisplay(confusion_matrix=cm_pop, display_labels=popularity_encoder.classes_)
disp_pop.plot(cmap=plt.cm.Blues, ax=axs[1], xticks_rotation='vertical')
axs[1].set_title('Confusion Matrix for Popularity Category Prediction')

disp_rank = ConfusionMatrixDisplay(confusion_matrix=cm_rank, display_labels=rank_encoder.classes_)
disp_rank.plot(cmap=plt.cm.Blues, ax=axs[2], xticks_rotation='vertical')
axs[2].set_title('Confusion Matrix for Rank Category Prediction')

plt.tight_layout()
plt.show()

# %%
with open('prediction_model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
```
with open('score_encoder.pkl', 'wb') as file:
    pickle.dump(score_encoder, file)

with open('popularity_encoder.pkl', 'wb') as file:
    pickle.dump(popularity_encoder, file)

with open('rank_encoder.pkl', 'wb') as file:
```
